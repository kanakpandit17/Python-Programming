# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df_health=pd.read_csv('/content/drive/MyDrive/dataset1/healthcare_test_data.csv - healthcare_test_data.csv.csv')

# %%
print(df_health)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 3        318442              6                  a                   6
# 4        318443             28                  b                  11
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
df_health.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# ...

# %%
df_health.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
df1=df_health.head(2)
df2=df_health.tail(2)
print(pd.concat([df1,df2]))   #join the first two and last two values
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                         Z                                  3  gynecology
# 1                         X                                  2  gynecology
# 137055                    X                                  2  anesthesia
# 137056                    X                                  3  gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              S                  A        2.0      17006                2.0
# 1              S                  F        2.0      17006                2.0
# ...

# %%
df3=df_health[df_health['Hospital_code']>=30]
print(df3.sort_values('Hospital_code',ascending=True)) #print details where hospital_code is more than 30 and arrange in asceding order of their code
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137054   455493             30                  c                   3
# 85105    403544             30                  c                   3
# 29090    347529             30                  c                   3
# 29091    347530             30                  c                   3
# 29092    347531             30                  c                   3
# ...         ...            ...                ...                 ...
# 32098    350537             32                  f                   9
# 32100    350539             32                  f                   9
# 79994    398433             32                  f                   9
# 32077    350516             32                  f                   9
# 20       318459             32                  f                   9
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
print(df3)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 20       318459             32                  f                   9
# 31       318470             31                  c                   3
# 50       318489             32                  f                   9
# 51       318490             32                  f                   9
# 70       318509             32                  f                   9
# ...         ...            ...                ...                 ...
# 137014   455453             31                  c                   3
# 137024   455463             32                  f                   9
# 137026   455465             30                  c                   3
# 137027   455466             32                  f                   9
# 137054   455493             30                  c                   3
#
#        Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# ...

# %%
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137057 entries, 0 to 137056
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            137057 non-null  int64
#  1   Hospital_code                      137057 non-null  int64
#  2   Hospital_type_code                 137057 non-null  object
#  3   City_Code_Hospital                 137057 non-null  int64
#  4   Hospital_region_code               137057 non-null  object
#  5   Available Extra Rooms in Hospital  137057 non-null  int64
#  6   Department                         137057 non-null  object
#  7   Ward_Type                          137057 non-null  object
#  8   Ward_Facility_Code                 137057 non-null  object
#  9   Bed Grade                          137022 non-null  float64
#  10  patientid                          137057 non-null  int64
# ...

# %%
df1=df_health.sort_values('Hospital_code',ascending=True)
df1
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 106366   424805              1                  d                  10
# 40087    358526              1                  d                  10
# 107645   426084              1                  d                  10
# 5642     324081              1                  d                  10
# 86259    404698              1                  d                  10
# ...         ...            ...                ...                 ...
# 39199    357638             32                  f                   9
# 27903    346342             32                  f                   9
# 55600    374039             32                  f                   9
# 110562   429001             32                  f                   9
# 19303    337742             32                  f                   9
#
#        Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# ...

# %%
df4=df_health[(df_health['City_Code_Hospital']==9) & (df_health['Type of Admission']=='Trauma')]
df4
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 70       318509             32                  f                   9
# 79       318518             22                  g                   9
# 107      318546             32                  f                   9
# 177      318616             22                  g                   9
# 186      318625             32                  f                   9
# ...         ...            ...                ...                 ...
# 136913   455352             22                  g                   9
# 136938   455377             32                  f                   9
# 136969   455408             32                  f                   9
# 136970   455409             22                  g                   9
# 137025   455464             22                  g                   9
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
df_health.drop(['Ward_Type'],axis=1,inplace=True)
df_health.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0                  A        2.0      17006                2.0
# ...

# %%
print(df_health)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 3        318442              6                  a                   6
# 4        318443             28                  b                  11
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...
